# %%
import saspy
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science libraries jupyter and notebook are not installed in interpreter Python 2.7.17 64-bit.
# at b.startServer (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:48:270430)
# at processTicksAndRejections (internal/process/task_queues.js:97:5)
# at async b.createServer (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:48:269873)
# at async connect (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:48:397876)
# at async w.ensureConnectionAndNotebookImpl (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:16:571752)
# at async w.ensureConnectionAndNotebook (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:16:571430)
# at async w.clearResult (/config/extensions/ms-python.python-2020.5.86806/out/client/extension.js:16:567473)
# ...

# %%
sas = saspy.SASsession(cfgfile='/usr/local/lib/python3.8/dist-packages/saspy/sascfg.py')
# Out:
# Using SAS Config named: sas94
# Please enter the IOM user id: sas
# Please enter the password for IOM user : ········
# SAS Connection established. Subprocess id is 65
#
# No encoding value provided. Will try to determine the correct encoding.
# Setting encoding to latin_1 based upon the SAS session encoding value of latin1.

# %%
cars = sas.sasdata('cars', 'sashelp')

# %%
cars
# Out:
# Libref  = sashelp
# Table   = cars
# Dsopts  = {}
# Results = Pandas

# %%
cars.columnInfo()
# Out:
#           Member  Num     Variable  Type  Len  Pos    Format            Label
# 0   SASHELP.CARS    9    Cylinders   Num    8   24       NaN              NaN
# 1   SASHELP.CARS    5   DriveTrain  Char    5  147       NaN              NaN
# 2   SASHELP.CARS    8   EngineSize   Num    8   16       NaN  Engine Size (L)
# 3   SASHELP.CARS   10   Horsepower   Num    8   32       NaN              NaN
# 4   SASHELP.CARS    7      Invoice   Num    8    8  DOLLAR8.              NaN
# 5   SASHELP.CARS   15       Length   Num    8   72       NaN      Length (IN)
# 6   SASHELP.CARS   11     MPG_City   Num    8   40       NaN       MPG (City)
# 7   SASHELP.CARS   12  MPG_Highway   Num    8   48       NaN    MPG (Highway)
# 8   SASHELP.CARS    6         MSRP   Num    8    0  DOLLAR8.              NaN
# 9   SASHELP.CARS    1         Make  Char   13   80       NaN              NaN
# 10  SASHELP.CARS    2        Model  Char   40   93       NaN              NaN
# ...

# %%
cars.heatmap("Cylinders","EngineSize")
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
cars.means()
# Out:
#       Variable            Label    N  NMiss   Median          Mean  \
# 0         MSRP              NaN  428      0  27635.0  32774.855140
# 1      Invoice              NaN  428      0  25294.5  30014.700935
# 2   EngineSize  Engine Size (L)  428      0      3.0      3.196729
# 3    Cylinders              NaN  426      2      6.0      5.807512
# 4   Horsepower              NaN  428      0    210.0    215.885514
# 5     MPG_City       MPG (City)  428      0     19.0     20.060748
# 6  MPG_Highway    MPG (Highway)  428      0     26.0     26.843458
# 7       Weight     Weight (LBS)  428      0   3474.5   3577.953271
# 8    Wheelbase   Wheelbase (IN)  428      0    107.0    108.154206
# 9       Length      Length (IN)  428      0    187.0    186.362150
#
#          StdDev      Min       P25      P50      P75       Max
# 0  19431.716674  10280.0  20329.50  27635.0  39215.0  192465.0
# 1  17642.117750   9875.0  18851.00  25294.5  35732.5  173560.0
# ...
